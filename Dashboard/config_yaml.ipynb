# %%
with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
import yaml

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

print(config["anomaly_detection"]["threshold_value"])
# Out:
# 50
